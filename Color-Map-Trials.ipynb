# %% [markdown]
# # Color Map
# Radhika Kanwar <br>
# GF202344308

# %%
class CSP:
    def __init__(self, variables, domains, constraints):
        self.variables = variables
        self.domains = domains
        self.constraints = constraints
        self.solution = None

    def solve(self):
        assignment = {}
        self.solution = self.backtrack(assignment)
        return self.solution

    def backtrack(self, assignment):
        if len(assignment) == len(self.variables):
            return assignment

        var = self.select_unassigned_variable(assignment)
        for value in self.order_domain_values(var, assignment):
            if self.is_consistent(var, value, assignment):
                assignment[var] = value
                result = self.backtrack(assignment)
                if result is not None:
                    return result
                del assignment[var]
        return None

    def select_unassigned_variable(self, assignment):
        unassigned_vars = [var for var in self.variables if var not in assignment]
        return min(unassigned_vars, key=lambda var: len(self.domains[var]))

    def order_domain_values(self, var, assignment):
        return self.domains[var]

    def is_consistent(self, var, value, assignment):
        for constraint_var in self.constraints[var]:
            if constraint_var in assignment and assignment[constraint_var] == value:
                return False
        return True

# Setting up the map for India with all states and Union Territories

# Define the variables (Indian states and Union Territories)
variables = [
    'Andhra Pradesh', 'Arunachal Pradesh', 'Assam', 'Bihar', 'Chhattisgarh',
    'Goa', 'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jharkhand',
    'Karnataka', 'Kerala', 'Madhya Pradesh', 'Maharashtra', 'Manipur',
    'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha', 'Punjab',
    'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana', 'Tripura',
    'Uttar Pradesh', 'Uttarakhand', 'West Bengal',
    'Andaman and Nicobar Islands', 'Chandigarh', 'Dadra and Nagar Haveli and Daman and Diu',
    'Lakshadweep', 'Delhi', 'Puducherry'
]

# Define the domains (colors)
domains = {
    'Andhra Pradesh': ['Sky Blue', 'Golden Yellow'],
    'Arunachal Pradesh': ['Forest Green', 'Light Brown'],
    'Assam': ['Tea Green', 'Rich Brown'],
    'Bihar': ['Saffron', 'Earthy Red'],
    'Chhattisgarh': ['Emerald Green', 'Deep Blue'],
    'Goa': ['Turquoise', 'Sunset Orange'],
    'Gujarat': ['Saffron', 'Green'],
    'Haryana': ['Wheat Yellow', 'Deep Green'],
    'Himachal Pradesh': ['Snow White', 'Pine Green'],
    'Jharkhand': ['Dark Green', 'Rust Brown'],
    'Karnataka': ['Navy Blue', 'Gold'],
    'Kerala': ['Emerald Green', 'Ocean Blue'],
    'Madhya Pradesh': ['Forest Green', 'Brown'],
    'Maharashtra': ['Navy Blue', 'Gold'],
    'Manipur': ['Royal Blue', 'Violet'],
    'Meghalaya': ['Sky Blue', 'White'],
    'Mizoram': ['Vibrant Orange', 'Charcoal'],
    'Nagaland': ['Deep Red', 'Dark Green'],
    'Odisha': ['Coral', 'Golden Yellow'],
    'Punjab': ['Royal Purple', 'Bright Yellow'],
    'Rajasthan': ['Desert Orange', 'Royal Blue'],
    'Sikkim': ['Mountain Gray', 'Forest Green'],
    'Tamil Nadu': ['Red', 'Cream'],
    'Telangana': ['Dark Blue', 'Golden Yellow'],
    'Tripura': ['Peach', 'Maroon'],
    'Uttar Pradesh': ['Sky Blue', 'Maroon'],
    'Uttarakhand': ['Mountain Green', 'Light Gray'],
    'West Bengal': ['Bengal Blue', 'Yellow'],
    'Andaman and Nicobar Islands': ['Aqua Blue', 'Coral Red'],
    'Chandigarh': ['Pastel Pink', 'Gray'],
    'Dadra and Nagar Haveli and Daman and Diu': ['Light Brown', 'Cream'],
    'Lakshadweep': ['Turquoise', 'Sunset Pink'],
    'Delhi': ['Red', 'White'],
    'Puducherry': ['Sunset Orange', 'Vibrant Yellow']
}

# Define the constraints (adjacent states)
constraints = {
    'Andhra Pradesh': ['Tamil Nadu', 'Karnataka', 'Telangana', 'Odisha'],
    'Arunachal Pradesh': ['Assam', 'Nagaland'],
    'Assam': ['Arunachal Pradesh', 'Nagaland', 'Manipur', 'West Bengal'],
    'Bihar': ['Uttar Pradesh', 'Jharkhand', 'West Bengal'],
    'Chhattisgarh': ['Madhya Pradesh', 'Odisha', 'Jharkhand', 'Maharashtra'],
    'Goa': ['Maharashtra', 'Karnataka'],
    'Gujarat': ['Maharashtra', 'Rajasthan'],
    'Haryana': ['Punjab', 'Uttar Pradesh', 'Rajasthan'],
    'Himachal Pradesh': ['Punjab', 'Uttarakhand', 'Haryana'],
    'Jharkhand': ['Bihar', 'Odisha', 'Chhattisgarh', 'West Bengal'],
    'Karnataka': ['Maharashtra', 'Goa', 'Andhra Pradesh', 'Tamil Nadu'],
    'Kerala': ['Tamil Nadu', 'Karnataka'],
    'Madhya Pradesh': ['Maharashtra', 'Gujarat', 'Chhattisgarh', 'Uttar Pradesh'],
    'Maharashtra': ['Gujarat', 'Madhya Pradesh', 'Goa', 'Karnataka'],
    'Manipur': ['Assam', 'Nagaland'],
    'Meghalaya': ['Assam', 'Nagaland'],
    'Mizoram': ['Manipur', 'Tripura'],
    'Nagaland': ['Manipur', 'Assam', 'Arunachal Pradesh'],
    'Odisha': ['West Bengal', 'Chhattisgarh', 'Andhra Pradesh'],
    'Punjab': ['Haryana', 'Himachal Pradesh', 'Uttar Pradesh'],
    'Rajasthan': ['Gujarat', 'Madhya Pradesh', 'Haryana'],
    'Sikkim': ['West Bengal', 'Bhutan'],
    'Tamil Nadu': ['Karnataka', 'Andhra Pradesh', 'Kerala'],
    'Telangana': ['Maharashtra', 'Andhra Pradesh', 'Chhattisgarh'],
    'Tripura': ['Assam', 'Mizoram'],
    'Uttar Pradesh': ['Bihar', 'Madhya Pradesh', 'Haryana', 'Delhi', 'Uttarakhand'],
    'Uttarakhand': ['Himachal Pradesh', 'Uttar Pradesh'],
    'West Bengal': ['Assam', 'Bihar', 'Sikkim', 'Jharkhand'],
    'Andaman and Nicobar Islands': [],
    'Chandigarh': ['Punjab', 'Haryana'],
    'Dadra and Nagar Haveli and Daman and Diu': ['Gujarat'],
    'Lakshadweep': [],
    'Delhi': ['Uttar Pradesh', 'Haryana', 'Rajasthan'],
    'Puducherry': ['Tamil Nadu']
}

# Create the CSP instance
csp = CSP(variables, domains, constraints)

# Solve the CSP
solution = csp.solve()

if solution:
    print("In the diverse land of India, each state has been beautifully painted!")
    for state, color in solution.items():
        print(f"The vibrant state of '{state}' is adorned in {color}.")
else:
    print("Alas, India's colors could not be arranged without conflict!")
# Out:
# In the diverse land of India, each state has been beautifully painted!
# The vibrant state of 'Andhra Pradesh' is adorned in Sky Blue.
# The vibrant state of 'Arunachal Pradesh' is adorned in Forest Green.
# The vibrant state of 'Assam' is adorned in Tea Green.
# The vibrant state of 'Bihar' is adorned in Saffron.
# The vibrant state of 'Chhattisgarh' is adorned in Emerald Green.
# The vibrant state of 'Goa' is adorned in Turquoise.
# The vibrant state of 'Gujarat' is adorned in Saffron.
# The vibrant state of 'Haryana' is adorned in Wheat Yellow.
# The vibrant state of 'Himachal Pradesh' is adorned in Snow White.
# The vibrant state of 'Jharkhand' is adorned in Dark Green.
# The vibrant state of 'Karnataka' is adorned in Navy Blue.
# The vibrant state of 'Kerala' is adorned in Emerald Green.
# The vibrant state of 'Madhya Pradesh' is adorned in Forest Green.
# The vibrant state of 'Maharashtra' is adorned in Gold.
# The vibrant state of 'Manipur' is adorned in Royal Blue.
# The vibrant state of 'Meghalaya' is adorned in Sky Blue.
# The vibrant state of 'Mizoram' is adorned in Vibrant Orange.
# The vibrant state of 'Nagaland' is adorned in Deep Red.
# The vibrant state of 'Odisha' is adorned in Coral.
# The vibrant state of 'Punjab' is adorned in Royal Purple.
# The vibrant state of 'Rajasthan' is adorned in Desert Orange.
# The vibrant state of 'Sikkim' is adorned in Mountain Gray.
# The vibrant state of 'Tamil Nadu' is adorned in Red.
# The vibrant state of 'Telangana' is adorned in Dark Blue.
# The vibrant state of 'Tripura' is adorned in Peach.
# The vibrant state of 'Uttar Pradesh' is adorned in Sky Blue.
# The vibrant state of 'Uttarakhand' is adorned in Mountain Green.
# The vibrant state of 'West Bengal' is adorned in Bengal Blue.
# The vibrant state of 'Andaman and Nicobar Islands' is adorned in Aqua Blue.
# The vibrant state of 'Chandigarh' is adorned in Pastel Pink.
# The vibrant state of 'Dadra and Nagar Haveli and Daman and Diu' is adorned in Light Brown.
# The vibrant state of 'Lakshadweep' is adorned in Turquoise.
# The vibrant state of 'Delhi' is adorned in Red.
# The vibrant state of 'Puducherry' is adorned in Sunset Orange.

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import mapping

class CSP:
    def __init__(self, variables, domains, constraints):
        self.variables = variables
        self.domains = domains
        self.constraints = constraints
        self.solution = None

    def solve(self):
        assignment = {}
        self.solution = self.backtrack(assignment)
        return self.solution

    def backtrack(self, assignment):
        if len(assignment) == len(self.variables):
            return assignment

        var = self.select_unassigned_variable(assignment)
        for value in self.order_domain_values(var, assignment):
            if self.is_consistent(var, value, assignment):
                assignment[var] = value
                result = self.backtrack(assignment)
                if result is not None:
                    return result
                del assignment[var]
        return None

    def select_unassigned_variable(self, assignment):
        unassigned_vars = [var for var in self.variables if var not in assignment]
        return min(unassigned_vars, key=lambda var: len(self.domains[var]))

    def order_domain_values(self, var, assignment):
        return self.domains[var]

    def is_consistent(self, var, value, assignment):
        for constraint_var in self.constraints[var]:
            if constraint_var in assignment and assignment[constraint_var] == value:
                return False
        return True

variables = [
    'Andhra Pradesh', 'Arunachal Pradesh', 'Assam', 'Bihar', 'Chhattisgarh',
    'Goa', 'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jharkhand',
    'Karnataka', 'Kerala', 'Madhya Pradesh', 'Maharashtra', 'Manipur',
    'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha', 'Punjab',
    'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana', 'Tripura',
    'Uttar Pradesh', 'Uttarakhand', 'West Bengal',
    'Andaman and Nicobar Islands', 'Chandigarh', 'Dadra and Nagar Haveli and Daman and Diu',
    'Lakshadweep', 'Delhi', 'Puducherry','Jammu and Kashmir'
]

domains = {
    'Andhra Pradesh': ['skyblue', 'gold'],  # Sky Blue, Golden Yellow
    'Arunachal Pradesh': ['forestgreen', 'tan'],  # Forest Green, Light Brown
    'Assam': ['lightgreen', 'brown'],  # Tea Green, Rich Brown
    'Bihar': ['gold', 'firebrick'],  # Saffron, Earthy Red
    'Chhattisgarh': ['mediumseagreen', 'blue'],  # Emerald Green, Deep Blue
    'Goa': ['deepskyblue', 'orange'],  # Turquoise, Sunset Orange
    'Gujarat': ['orange', 'green'],  # Saffron, Green
    'Haryana': ['khaki', 'darkgreen'],  # Wheat Yellow, Deep Green
    'Himachal Pradesh': ['white', 'forestgreen'],  # Snow White, Pine Green
    'Jharkhand': ['darkgreen', 'sienna'],  # Dark Green, Rust Brown
    'Karnataka': ['navy', 'gold'],  # Navy Blue, Gold
    'Kerala': ['mediumseagreen', 'deepskyblue'],  # Emerald Green, Ocean Blue
    'Madhya Pradesh': ['forestgreen', 'saddlebrown'],  # Forest Green, Brown
    'Maharashtra': ['navy', 'gold'],  # Navy Blue, Gold
    'Manipur': ['royalblue', 'violet'],  # Royal Blue, Violet
    'Meghalaya': ['skyblue', 'white'],  # Sky Blue, White
    'Mizoram': ['orange', 'gray'],  # Vibrant Orange, Charcoal
    'Nagaland': ['darkred', 'darkgreen'],  # Deep Red, Dark Green
    'Odisha': ['coral', 'gold'],  # Coral, Golden Yellow
    'Punjab': ['purple', 'yellow'],  # Royal Purple, Bright Yellow
    'Rajasthan': ['orange', 'royalblue'],  # Desert Orange, Royal Blue
    'Sikkim': ['lightgray', 'forestgreen'],  # Mountain Gray, Forest Green
    'Tamil Nadu': ['red', 'beige'],  # Red, Cream
    'Telangana': ['darkblue', 'gold'],  # Dark Blue, Golden Yellow
    'Tripura': ['peachpuff', 'maroon'],  # Peach, Maroon
    'Uttar Pradesh': ['skyblue', 'maroon'],  # Sky Blue, Maroon
    'Uttarakhand': ['forestgreen', 'lightgray'],  # Mountain Green, Light Gray
    'West Bengal': ['blue', 'yellow'],  # Bengal Blue, Yellow
    'Andaman and Nicobar Islands': ['lightblue', 'red'],  # Aqua Blue, Coral Red
    'Chandigarh': ['pink', 'gray'],  # Pastel Pink, Gray
    'Dadra and Nagar Haveli and Daman and Diu': ['tan', 'beige'],  # Light Brown, Cream
    'Lakshadweep': ['deepskyblue', 'lightpink'],  # Turquoise, Sunset Pink
    'Delhi': ['red', 'white'],  # Red, White
    'Puducherry': ['orange', 'yellow'],  # Sunset Orange, Vibrant Yellow
    'Jammu and Kashmir': ['lightblue', 'darkgreen']
}

constraints = {
    'Andhra Pradesh': ['Tamil Nadu', 'Karnataka', 'Telangana', 'Odisha'],
    'Arunachal Pradesh': ['Assam', 'Nagaland'],
    'Assam': ['Arunachal Pradesh', 'Nagaland', 'Manipur', 'West Bengal'],
    'Bihar': ['Uttar Pradesh', 'Jharkhand', 'West Bengal'],
    'Chhattisgarh': ['Madhya Pradesh', 'Odisha', 'Jharkhand', 'Maharashtra'],
    'Goa': ['Maharashtra', 'Karnataka'],
    'Gujarat': ['Maharashtra', 'Rajasthan'],
    'Haryana': ['Punjab', 'Uttar Pradesh', 'Rajasthan'],
    'Himachal Pradesh': ['Punjab', 'Uttarakhand', 'Haryana'],
    'Jharkhand': ['Bihar', 'Odisha', 'Chhattisgarh', 'West Bengal'],
    'Karnataka': ['Maharashtra', 'Goa', 'Andhra Pradesh', 'Tamil Nadu'],
    'Kerala': ['Tamil Nadu', 'Karnataka'],
    'Madhya Pradesh': ['Maharashtra', 'Gujarat', 'Chhattisgarh', 'Uttar Pradesh'],
    'Maharashtra': ['Gujarat', 'Madhya Pradesh', 'Goa', 'Karnataka'],
    'Manipur': ['Assam', 'Nagaland'],
    'Meghalaya': ['Assam', 'Nagaland'],
    'Mizoram': ['Manipur', 'Tripura'],
    'Nagaland': ['Manipur', 'Assam', 'Arunachal Pradesh'],
    'Odisha': ['West Bengal', 'Chhattisgarh', 'Andhra Pradesh'],
    'Punjab': ['Haryana', 'Himachal Pradesh', 'Uttar Pradesh'],
    'Rajasthan': ['Gujarat', 'Madhya Pradesh', 'Haryana'],
    'Sikkim': ['West Bengal', 'Bhutan'],
    'Tamil Nadu': ['Karnataka', 'Andhra Pradesh', 'Kerala'],
    'Telangana': ['Maharashtra', 'Andhra Pradesh', 'Chhattisgarh'],
    'Tripura': ['Assam', 'Mizoram'],
    'Uttar Pradesh': ['Bihar', 'Madhya Pradesh', 'Haryana', 'Delhi', 'Uttarakhand'],
    'Uttarakhand': ['Himachal Pradesh', 'Uttar Pradesh'],
    'West Bengal': ['Assam', 'Bihar', 'Sikkim', 'Jharkhand'],
    'Andaman and Nicobar Islands': [],
    'Chandigarh': ['Punjab', 'Haryana'],
    'Dadra and Nagar Haveli and Daman and Diu': ['Gujarat'],
    'Lakshadweep': [],
    'Delhi': ['Uttar Pradesh', 'Haryana', 'Rajasthan'],
    'Puducherry': ['Tamil Nadu'],
    'Jammu and Kashmir': ['Himachal Pradesh', 'Punjab', 'Haryana']
}

# Create the CSP instance
csp = CSP(variables, domains, constraints)

# Solve the CSP
solution = csp.solve()

# Load the map of India
gdf = gpd.read_file('indian-states.txt')

# Prepare a color mapping based on the solution
color_mapping = {}
if solution:
    for region, color in solution.items():
        color_mapping[region] = color

# Map colors to a format suitable for GeoDataFrame
color_list = []
for state in gdf['NAME_1']: 
    color_list.append(color_mapping.get(state, 'black'))  # Default color for unmapped regions

# Plotting the map
gdf.plot(color=color_list, legend=True)
plt.title('Colored Map of India')
plt.axis('off')  # Hide axes
plt.show()

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import mapping

class CSP:
    def __init__(self, variables, domains, constraints):
        self.variables = variables
        self.domains = domains
        self.constraints = constraints
        self.solution = None

    def solve(self):
        assignment = {}
        self.solution = self.backtrack(assignment)
        return self.solution

    def backtrack(self, assignment):
        if len(assignment) == len(self.variables):
            return assignment

        var = self.select_unassigned_variable(assignment)
        for value in self.order_domain_values(var, assignment):
            if self.is_consistent(var, value, assignment):
                assignment[var] = value
                result = self.backtrack(assignment)
                if result is not None:
                    return result
                del assignment[var]
        return None

    def select_unassigned_variable(self, assignment):
        unassigned_vars = [var for var in self.variables if var not in assignment]
        return min(unassigned_vars, key=lambda var: len(self.domains[var]))

    def order_domain_values(self, var, assignment):
        return self.domains[var]

    def is_consistent(self, var, value, assignment):
        for constraint_var in self.constraints[var]:
            if constraint_var in assignment and assignment[constraint_var] == value:
                return False
        return True

variables = [
    'Andhra Pradesh', 'Arunachal Pradesh', 'Assam', 'Bihar', 'Chhattisgarh',
    'Goa', 'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jharkhand',
    'Karnataka', 'Kerala', 'Madhya Pradesh', 'Maharashtra', 'Manipur',
    'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha', 'Punjab',
    'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana', 'Tripura',
    'Uttar Pradesh', 'Uttarakhand', 'West Bengal',
    'Andaman and Nicobar Islands', 'Chandigarh', 'Dadra and Nagar Haveli and Daman and Diu',
    'Lakshadweep', 'Delhi', 'Puducherry','Jammu and Kashmir', 'Ladakh'
]

domains = {
    'Andhra Pradesh': ['skyblue', 'gold'], 
    'Arunachal Pradesh': ['forestgreen', 'tan'],
    'Assam': ['lightgreen', 'brown'],
    'Bihar': ['gold', 'firebrick'],
    'Chhattisgarh': ['mediumseagreen', 'blue'],
    'Goa': ['deepskyblue', 'orange'],
    'Gujarat': ['orange', 'green'],
    'Haryana': ['khaki', 'darkgreen'],
    'Himachal Pradesh': ['white', 'forestgreen'],
    'Jharkhand': ['darkgreen', 'sienna'], 
    'Karnataka': ['navy', 'gold'], 
    'Kerala': ['mediumseagreen', 'deepskyblue'],
    'Madhya Pradesh': ['forestgreen', 'saddlebrown'],
    'Maharashtra': ['navy', 'gold'],
    'Manipur': ['royalblue', 'violet'], 
    'Meghalaya': ['skyblue', 'white'], 
    'Mizoram': ['orange', 'gray'],
    'Nagaland': ['darkred', 'darkgreen'], 
    'Odisha': ['coral', 'gold'], 
    'Punjab': ['purple', 'yellow'],  
    'Rajasthan': ['orange', 'royalblue'], 
    'Sikkim': ['lightgray', 'forestgreen'], 
    'Tamil Nadu': ['red', 'beige'],
    'Telangana': ['darkblue', 'gold'],
    'Tripura': ['peachpuff', 'maroon'], 
    'Uttar Pradesh': ['skyblue', 'maroon'],
    'Uttarakhand': ['forestgreen', 'lightgray'],
    'West Bengal': ['blue', 'yellow'],
    'Andaman and Nicobar Islands': ['lightblue', 'red'],  
    'Chandigarh': ['pink', 'gray'], 
    'Dadra and Nagar Haveli and Daman and Diu': ['tan', 'beige'], 
    'Lakshadweep': ['deepskyblue', 'lightpink'], 
    'Delhi': ['red', 'white'],
    'Puducherry': ['orange', 'yellow'],
    'Jammu and Kashmir': ['lightblue', 'darkgreen'],
    'Ladakh':['lightblue', 'darkblue']
}

constraints = {
    'Andhra Pradesh': ['Tamil Nadu', 'Karnataka', 'Telangana', 'Chhattisgarh', 'Odisha'],
    'Arunachal Pradesh': ['Assam', 'Nagaland'],
    'Assam': ['Arunachal Pradesh', 'West Bengal','Meghalaya','Nagaland', 'Manipur', 'West Bengal','Tripura','Mizoram'],
    'Bihar': ['Uttar Pradesh', 'Jharkhand', 'West Bengal'],
    'Chhattisgarh': ['Madhya Pradesh', 'Odisha', 'Jharkhand', 'Maharashtra','Uttar Pradesh','Andhra Pradesh'],
    'Goa': ['Maharashtra', 'Karnataka'],
    'Gujarat': ['Maharashtra', 'Rajasthan'],
    'Haryana': ['Punjab', 'Uttar Pradesh', 'Rajasthan','Uttarakhand'],
    'Himachal Pradesh': ['Punjab', 'Uttarakhand', 'Haryana'],
    'Jharkhand': ['Bihar', 'Odisha', 'Chhattisgarh', 'West Bengal','Uttar Pradesh'],
    'Karnataka': ['Maharashtra', 'Goa', 'Andhra Pradesh', 'Telangana' 'Tamil Nadu'],
    'Kerala': ['Tamil Nadu', 'Karnataka'],
    'Madhya Pradesh': ['Maharashtra', 'Gujarat', 'Chhattisgarh', 'Uttar Pradesh'],
    'Maharashtra': ['Gujarat', 'Madhya Pradesh', 'Goa', 'Karnataka','Chhattisgarh'],
    'Manipur': ['Assam', 'Nagaland'],
    'Meghalaya': ['Assam', 'Nagaland'],
    'Mizoram': ['Manipur', 'Tripura','Assam'],
    'Nagaland': ['Manipur', 'Assam', 'Arunachal Pradesh'],
    'Odisha': ['West Bengal', 'Chhattisgarh', 'Jharkhand', 'Andhra Pradesh'],
    'Punjab': ['Haryana', 'Himachal Pradesh', 'Uttar Pradesh','Rajasthan'],
    'Rajasthan': ['Gujarat', 'Madhya Pradesh', 'Haryana','Uttar Pradesh','Punjab'],
    'Sikkim': ['West Bengal'],
    'Tamil Nadu': ['Karnataka', 'Andhra Pradesh', 'Kerala'],
    'Telangana': ['Maharashtra', 'Andhra Pradesh', 'Chhattisgarh','Karnataka'],
    'Tripura': ['Assam', 'Mizoram'],
    'Uttar Pradesh': ['Bihar', 'Madhya Pradesh', 'Haryana', 'Delhi', 'Uttarakhand','Rajasthan','Chhattisgarh','Jharkhand'],
    'Uttarakhand': ['Himachal Pradesh', 'Uttar Pradesh','Haryana'],
    'West Bengal': ['Assam', 'Bihar', 'Sikkim', 'Jharkhand','Odisha'],
    'Andaman and Nicobar Islands': [],
    'Chandigarh': ['Punjab', 'Haryana'],
    'Dadra and Nagar Haveli and Daman and Diu': ['Gujarat'],
    'Lakshadweep': [],
    'Delhi': ['Uttar Pradesh', 'Haryana', 'Rajasthan'],
    'Puducherry': ['Tamil Nadu'],
    'Jammu and Kashmir': ['Himachal Pradesh', 'Punjab', 'Haryana'],
    'Ladakh':['Jammu and Kashmir', 'Himachal Pradesh']
}

# Creating the CSP instance
csp = CSP(variables, domains, constraints)

# Solving the CSP
solution = csp.solve()

# Loading the map of India
gdf = gpd.read_file('geoBoundaries-IND-ADM1.geojson')

# Preparing a color mapping based on the solution
color_mapping = {}
if solution:
    for region, color in solution.items():
        color_mapping[region] = color

color_list = []
for state in gdf['shapeName']: 
    color_list.append(color_mapping.get(state, 'black'))  # Default color for unmapped regions

# Plotting the map
gdf.plot(color=color_list)
plt.title('Colored Map of India')
plt.axis('off') 
plt.show()

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import mapping

class CSP:
    def __init__(self, variables, domains, constraints):
        self.variables = variables
        self.domains = domains
        self.constraints = constraints
        self.solution = None

    def solve(self):
        assignment = {}
        self.solution = self.backtrack(assignment)
        return self.solution

    def backtrack(self, assignment):
        if len(assignment) == len(self.variables):
            return assignment

        var = self.select_unassigned_variable(assignment)
        for value in self.order_domain_values(var, assignment):
            if self.is_consistent(var, value, assignment):
                assignment[var] = value
                result = self.backtrack(assignment)
                if result is not None:
                    return result
                del assignment[var]
        return None

    def select_unassigned_variable(self, assignment):
        unassigned_vars = [var for var in self.variables if var not in assignment]
        return min(unassigned_vars, key=lambda var: len(self.domains[var]))

    def order_domain_values(self, var, assignment):
        return self.domains[var]

    def is_consistent(self, var, value, assignment):
        for constraint_var in self.constraints[var]:
            if constraint_var in assignment and assignment[constraint_var] == value:
                return False
        return True

variables = [
    'Andhra Pradesh', 'Arunachal Pradesh', 'Assam', 'Bihar', 'Chhattisgarh',
    'Goa', 'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jharkhand',
    'Karnataka', 'Kerala', 'Madhya Pradesh', 'Maharashtra', 'Manipur',
    'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha', 'Punjab',
    'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana', 'Tripura',
    'Uttar Pradesh', 'Uttarakhand', 'West Bengal',
    'Andaman and Nicobar Islands', 'Chandigarh', 'Dadra and Nagar Haveli and Daman and Diu',
    'Lakshadweep', 'Delhi', 'Puducherry','Jammu and Kashmir', 'Ladakh'
]

domains = {var: ['red', 'green', 'blue', 'yellow'] for var in variables}

constraints = {
    'Andhra Pradesh': ['Tamil Nadu', 'Karnataka', 'Telangana', 'Chhattisgarh', 'Odisha'],
    'Arunachal Pradesh': ['Assam', 'Nagaland'],
    'Assam': ['Arunachal Pradesh', 'West Bengal','Meghalaya','Nagaland', 'Manipur', 'West Bengal','Tripura','Mizoram'],
    'Bihar': ['Uttar Pradesh', 'Jharkhand', 'West Bengal'],
    'Chhattisgarh': ['Madhya Pradesh', 'Odisha', 'Jharkhand', 'Maharashtra','Uttar Pradesh','Andhra Pradesh'],
    'Goa': ['Maharashtra', 'Karnataka'],
    'Gujarat': ['Maharashtra', 'Rajasthan'],
    'Haryana': ['Punjab', 'Uttar Pradesh', 'Rajasthan','Uttarakhand'],
    'Himachal Pradesh': ['Punjab', 'Uttarakhand', 'Haryana'],
    'Jharkhand': ['Bihar', 'Odisha', 'Chhattisgarh', 'West Bengal','Uttar Pradesh'],
    'Karnataka': ['Maharashtra', 'Goa', 'Andhra Pradesh', 'Telangana' 'Tamil Nadu'],
    'Kerala': ['Tamil Nadu', 'Karnataka'],
    'Madhya Pradesh': ['Maharashtra', 'Gujarat', 'Chhattisgarh', 'Uttar Pradesh'],
    'Maharashtra': ['Gujarat', 'Madhya Pradesh', 'Goa', 'Karnataka','Chhattisgarh'],
    'Manipur': ['Assam', 'Nagaland'],
    'Meghalaya': ['Assam', 'Nagaland'],
    'Mizoram': ['Manipur', 'Tripura','Assam'],
    'Nagaland': ['Manipur', 'Assam', 'Arunachal Pradesh'],
    'Odisha': ['West Bengal', 'Chhattisgarh', 'Jharkhand', 'Andhra Pradesh'],
    'Punjab': ['Haryana', 'Himachal Pradesh', 'Uttar Pradesh','Rajasthan'],
    'Rajasthan': ['Gujarat', 'Madhya Pradesh', 'Haryana','Uttar Pradesh','Punjab'],
    'Sikkim': ['West Bengal'],
    'Tamil Nadu': ['Karnataka', 'Andhra Pradesh', 'Kerala'],
    'Telangana': ['Maharashtra', 'Andhra Pradesh', 'Chhattisgarh','Karnataka'],
    'Tripura': ['Assam', 'Mizoram'],
    'Uttar Pradesh': ['Bihar', 'Madhya Pradesh', 'Haryana', 'Delhi', 'Uttarakhand','Rajasthan','Chhattisgarh','Jharkhand'],
    'Uttarakhand': ['Himachal Pradesh', 'Uttar Pradesh','Haryana'],
    'West Bengal': ['Assam', 'Bihar', 'Sikkim', 'Jharkhand','Odisha'],
    'Andaman and Nicobar Islands': [],
    'Chandigarh': ['Punjab', 'Haryana'],
    'Dadra and Nagar Haveli and Daman and Diu': ['Gujarat'],
    'Lakshadweep': [],
    'Delhi': ['Uttar Pradesh', 'Haryana', 'Rajasthan'],
    'Puducherry': ['Tamil Nadu'],
    'Jammu and Kashmir': ['Himachal Pradesh', 'Punjab', 'Haryana'],
    'Ladakh':['Jammu and Kashmir', 'Himachal Pradesh']
}

csp = CSP(variables, domains, constraints)
solution = csp.solve()

gdf = gpd.read_file('geoBoundaries-IND-ADM1.geojson')

color_mapping = {}
if solution:
    for region, color in solution.items():
        color_mapping[region] = color

color_list = []
for state in gdf['shapeName']: 
    color_list.append(color_mapping.get(state, 'black'))  # Default color for unmapped regions

# Plotting the map
gdf.plot(color=color_list)
plt.title('Colored Map of India')
plt.axis('off')
plt.show()

# %%
# !pip install folium
# Out:
# Collecting folium
#   Downloading folium-0.17.0-py2.py3-none-any.whl.metadata (3.8 kB)
# Collecting branca>=0.6.0 (from folium)
#   Downloading branca-0.8.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: jinja2>=2.9 in c:\anaconda3\lib\site-packages (from folium) (3.1.2)
# Requirement already satisfied: numpy in c:\anaconda3\lib\site-packages (from folium) (1.24.3)
# Requirement already satisfied: requests in c:\anaconda3\lib\site-packages (from folium) (2.31.0)
# Requirement already satisfied: xyzservices in c:\anaconda3\lib\site-packages (from folium) (2022.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (2.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\anaconda3\lib\site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\anaconda3\lib\site-packages (from requests->folium) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\anaconda3\lib\site-packages (from requests->folium) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\anaconda3\lib\site-packages (from requests->folium) (2023.7.22)
# Downloading folium-0.17.0-py2.py3-none-any.whl (108 kB)
# Downloading branca-0.8.0-py3-none-any.whl (25 kB)
# Installing collected packages: branca, folium
# Successfully installed branca-0.8.0 folium-0.17.0

# %%
import geopandas as gpd
import folium
from shapely.geometry import mapping

class CSP:
    def __init__(self, variables, domains, constraints):
        self.variables = variables
        self.domains = domains
        self.constraints = constraints
        self.solution = None

    def solve(self):
        assignment = {}
        self.solution = self.backtrack(assignment)
        return self.solution

    def backtrack(self, assignment):
        if len(assignment) == len(self.variables):
            return assignment

        var = self.select_unassigned_variable(assignment)
        for value in self.order_domain_values(var, assignment):
            if self.is_consistent(var, value, assignment):
                assignment[var] = value
                result = self.backtrack(assignment)
                if result is not None:
                    return result
                del assignment[var]
        return None

    def select_unassigned_variable(self, assignment):
        unassigned_vars = [var for var in self.variables if var not in assignment]
        return min(unassigned_vars, key=lambda var: len(self.domains[var]))

    def order_domain_values(self, var, assignment):
        return self.domains[var]

    def is_consistent(self, var, value, assignment):
        for constraint_var in self.constraints[var]:
            if constraint_var in assignment and assignment[constraint_var] == value:
                return False
        return True

variables = ['Andhra Pradesh', 'Arunachal Pradesh', 'Assam', 'Bihar', 'Chhattisgarh', 'Goa', 
             'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jharkhand', 'Karnataka', 'Kerala',
             'Madhya Pradesh', 'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland',
             'Odisha', 'Punjab', 'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana', 'Tripura',
             'Uttar Pradesh', 'Uttarakhand', 'West Bengal', 'Andaman and Nicobar Islands', 
             'Chandigarh', 'Dadra and Nagar Haveli and Daman and Diu', 'Lakshadweep', 'Delhi', 
             'Puducherry', 'Jammu and Kashmir', 'Ladakh']

domains = {var: ['red', 'green', 'blue', 'yellow'] for var in variables}

constraints = {
    'Andhra Pradesh': ['Tamil Nadu', 'Karnataka', 'Telangana', 'Chhattisgarh', 'Odisha'],
    'Arunachal Pradesh': ['Assam', 'Nagaland'],
    'Assam': ['Arunachal Pradesh', 'West Bengal','Meghalaya','Nagaland', 'Manipur', 'West Bengal','Tripura','Mizoram'],
    'Bihar': ['Uttar Pradesh', 'Jharkhand', 'West Bengal'],
    'Chhattisgarh': ['Madhya Pradesh', 'Odisha', 'Jharkhand', 'Maharashtra','Uttar Pradesh','Andhra Pradesh'],
    'Goa': ['Maharashtra', 'Karnataka'],
    'Gujarat': ['Maharashtra', 'Rajasthan'],
    'Haryana': ['Punjab', 'Uttar Pradesh', 'Rajasthan','Uttarakhand'],
    'Himachal Pradesh': ['Punjab', 'Uttarakhand', 'Haryana'],
    'Jharkhand': ['Bihar', 'Odisha', 'Chhattisgarh', 'West Bengal','Uttar Pradesh'],
    'Karnataka': ['Maharashtra', 'Goa', 'Andhra Pradesh', 'Telangana' 'Tamil Nadu'],
    'Kerala': ['Tamil Nadu', 'Karnataka'],
    'Madhya Pradesh': ['Maharashtra', 'Gujarat', 'Chhattisgarh', 'Uttar Pradesh'],
    'Maharashtra': ['Gujarat', 'Madhya Pradesh', 'Goa', 'Karnataka','Chhattisgarh'],
    'Manipur': ['Assam', 'Nagaland'],
    'Meghalaya': ['Assam', 'Nagaland'],
    'Mizoram': ['Manipur', 'Tripura','Assam'],
    'Nagaland': ['Manipur', 'Assam', 'Arunachal Pradesh'],
    'Odisha': ['West Bengal', 'Chhattisgarh', 'Jharkhand', 'Andhra Pradesh'],
    'Punjab': ['Haryana', 'Himachal Pradesh', 'Uttar Pradesh','Rajasthan'],
    'Rajasthan': ['Gujarat', 'Madhya Pradesh', 'Haryana','Uttar Pradesh','Punjab'],
    'Sikkim': ['West Bengal'],
    'Tamil Nadu': ['Karnataka', 'Andhra Pradesh', 'Kerala'],
    'Telangana': ['Maharashtra', 'Andhra Pradesh', 'Chhattisgarh','Karnataka'],
    'Tripura': ['Assam', 'Mizoram'],
    'Uttar Pradesh': ['Bihar', 'Madhya Pradesh', 'Haryana', 'Delhi', 'Uttarakhand','Rajasthan','Chhattisgarh','Jharkhand'],
    'Uttarakhand': ['Himachal Pradesh', 'Uttar Pradesh','Haryana'],
    'West Bengal': ['Assam', 'Bihar', 'Sikkim', 'Jharkhand','Odisha'],
    'Andaman and Nicobar Islands': [],
    'Chandigarh': ['Punjab', 'Haryana'],
    'Dadra and Nagar Haveli and Daman and Diu': ['Gujarat'],
    'Lakshadweep': [],
    'Delhi': ['Uttar Pradesh', 'Haryana', 'Rajasthan'],
    'Puducherry': ['Tamil Nadu'],
    'Jammu and Kashmir': ['Himachal Pradesh', 'Punjab', 'Haryana'],
    'Ladakh':['Jammu and Kashmir', 'Himachal Pradesh']
}


csp = CSP(variables, domains, constraints)
solution = csp.solve()

gdf = gpd.read_file('geoBoundaries-IND-ADM1.geojson')

color_mapping = {}
if solution:
    for region, color in solution.items():
        color_mapping[region] = color

# Create a folium map centered around India
m = folium.Map(location=[20.5937, 78.9629], zoom_start=5)

# Add colored states to the folium map
for idx, row in gdf.iterrows():
    state_name = row['shapeName']
    state_color = color_mapping.get(state_name, 'black')  # Default to black if not found
    geo_json = mapping(row['geometry'])
    
    # Adding state to the map with popup and color
    folium.GeoJson(
        geo_json,
        style_function=lambda x, color=state_color: {
            'fillColor': color,
            'color': 'black',
            'weight': 1.5,
            'fillOpacity': 0.7
        },
        tooltip=state_name
    ).add_to(m)

# Save to HTML
m.save("colored_map_of_india.html")
print("Map saved as 'colored_map_of_india.html'.")
# Out:
# Map saved as 'colored_map_of_india.html'.
